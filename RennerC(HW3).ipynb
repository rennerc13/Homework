# %% [markdown]
# # Homework 3
# ### 1.What is an algorithm?
# ##### Algorithm is a formula/steps to solve problems
# ### 2.Variable names may not start with certain characters - name two.
# ##### special characters and numbers
# ### 3.What is a Semantic error?
# ##### code is correct but doesnt make sense
# ### 4.What is the #1 rule of coding / debugging?
# ##### The #1 Rule: Complexity is the enemy of efficiency! Make it simple
# ### 5.List 5 Python reserved words.
# ##### False, True, pass, None, else

# %%
#6.Write a multi-line comment with your name, favorite food, and dream job on 3 different lines

multi_line= """
Name: Renner Castro
Favorite food: Steak 
Dream job: Data Analyst 
"""
print(multi_line)

#7.Assign 5 different data types to 5 different variables. At least one datatype must be a string

x1 = "Homework!"
x2 = True
x3 = 35
x4 = 35.5
x5 = ["banana", "apple", "orange"]

#Print the length of your string

print ("the length is ", len(x1))

#Print the index value of the 4th character in your string

print ("index value = ", x1[4])

#8.Create a new variable called savvy, and assign it the string with this phrase "Learning Data Analytics and Python is Awesome!"

savvy = "Learning Data Analytics and Python is Awesome!"

#Return a range of characters that slices the above string from the beginning of "ing" up to before "and"

print (savvy[5:23])

#Replace "Awesome" with "great" in the string

g = savvy.replace("Awesome", "great")
print(g)

#Test and print the savvy string to see it contains "Python"

print(savvy)

#9.Create and assign 3 more variables called name, age and length using the multi-variable naming method

name, age, length = "Mark", "25", "180 cm"

#Format a new string called 'miniBio' using variables in curly brackets to complete this phrase... "Hi my name is (name), I am (tall) and (so) old today."

minibio = "Hi my name is {}, I am {} and {} old today"

#Print 'miniBio'

print(minibio.format(name, length, age))

#Cast and print the age variable to a float

age = float(20)
print (age)
# Out:
# Name: Renner Castro
# Favorite food: Steak
# Dream job: Data Analyst
#
# the length is  9
# index value =  w
# ing Data Analytics
# Learning Data Analytics and Python is great!
# Learning Data Analytics and Python is Awesome!
# Hi my name is Mark, I am 180 cm and 25 old today
# 20.0

# %%
#10Create a list of at least 5 elements of mixed data types

list1 = ["elements",25, 3.1, True, [1,2,3,4,5]]

#Replace a part of it with something else
                                       
list1[0] = "replaced"

#Append or insert several more items to the list

list1.append("car")
list1.append(False)

#Find and print the length of the list

print(len(list1))

#Slice a sub-section of the 1st list, and save it to a different 2nd list

list2 = list1[1:4]

#Print the 2nd list

print(list2)

#Extend your original list with the 2nd list sliced above

list1.extend(list2)
print(list1)

#Create a new list called "simList" containing at least 5 elements of the same data type, either string, integer, float, or Boolean

simlist = [12,4,26,8,10]

#Sort "simList", and print the list

simlist.sort()
print(simlist)

#Copy the "simList" list to another 3rd list

simlist3 = simlist.copy()

#Add the 2nd and 3rd lists together into a 4th list

simlist4 = simlist + simlist3 
print(simlist4)
# Out:
# 7
# [25, 3.1, True]
# ['replaced', 25, 3.1, True, [1, 2, 3, 4, 5], 'car', False, 25, 3.1, True]
# [4, 8, 10, 12, 26]
# [4, 8, 10, 12, 26, 4, 8, 10, 12, 26]

# %%
# Create a tuple of about 5 elements

tuple1 = (6, 3, 2, 4, 5)

# Multiply your tuple by 3 and save it to a new 2nd tuple

tuple2 = tuple1 * 3

# Access and print the 12th element from the 2nd tuple

print(tuple2[11])

# Sort the 2nd tuple and print it

sortedtup = tuple(sorted(tuple2))
print(sortedtup)

# Copy 4 specific elements from your 2nd tuple to a new 3rd tuple

tuple3 = tuple2[2:6]
print(tuple3)


# Unpack the 3rd tuple into 4 variables and print these variables

var1, var2, var3, var4 = tuple3
print(var1, var2, var3, var4)

# Create a 4th tuple with a single item 50

tuple4 = (50,)

# Add the 2nd and 3rd tuples together into a 5th tuple and print the tuple

tuple5 = tuple2 + tuple3
print(tuple5)
# Out:
# 3
# (2, 2, 2, 3, 3, 3, 4, 4, 4, 5, 5, 5, 6, 6, 6)
# (2, 4, 5, 6)
# 2 4 5 6
# (6, 3, 2, 4, 5, 6, 3, 2, 4, 5, 6, 3, 2, 4, 5, 2, 4, 5, 6)

# %%
#12. Create a set of about 3 elements

set1 = {1,2,3}

#Add a list of fruits to the above set and print the result

set1.add("apple")
set1.add("banana")
set1.add("strawberry")
print(set1)

#Add a car element to your set

set1.add("Kia")

#Create a 2nd set with a few odd items

set2 = {"pencil", "paper clip", "eraser"}

#Save the union of 1st set and 2nd set to a 3rd set

set3 = set1.union(set2)

#Pop an element from the 2nd set, and print the remainder of the set

set2.remove("paper clip")
print(set2)

#Clear the 1st set and print the result

set1.clear()
print(set1)


#Discard an element, and remove another element from the 3rd set

set3.remove("strawberry")
set3.remove(1)


#Print the remainder of the 3rd set

print(set3)
# Out:
# {1, 2, 3, 'apple', 'strawberry', 'banana'}
# {'eraser', 'pencil'}
# set()
# {2, 3, 'apple', 'Kia', 'pencil', 'banana', 'eraser', 'paper clip'}

# %%
#Create a dictionary with at least 5 values of different data types

dict1 = {"count": 5, "float": 1.23, "bool": True, "list1":[1, 2, 3], "car": "ford" }

#Print out 1 value

print(dict1["car"])

#Replace any one value in your dictionary with your name

dict1["car"] = "Elon"

#Add your favorite color to the dictionary

dict1["color"] = "red"

#Add a list, tuple or set to your dictionary

dict1["tuples"] = ("one", "two", "three")

#Print a list of the dictionary keys

print(dict1.keys())

#Print a list of the dictionary values

print(dict1.values())

#Copy your 1st dictionary into a 2nd dictionary

dict2 = dict1.copy()

#Pop an item from the 2nd dictionary, and print the dictionary

dict2.popitem()
print(dict2)

#Remove all the elements from the 2nd dictionary and print the result

dict2.clear()
print(dict2)
# Out:
# ford
# dict_keys(['count', 'float', 'bool', 'list1', 'car', 'color', 'tuples'])
# dict_values([5, 1.23, True, [1, 2, 3], 'Elon', 'red', ('one', 'two', 'three')])
# {'count': 5, 'float': 1.23, 'bool': True, 'list1': [1, 2, 3], 'car': 'Elon', 'color': 'red'}
# {}
